# %%
import torch
torch.__version__, torch.cuda.is_available()
# Out:
# /opt/miniconda/envs/torch-nightly/lib/python3.11/site-packages/torch/_subclasses/functional_tensor.py:307: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# ('2.11.0.dev20260123+cpu', False)

# %%
import torch
torch.__version__, torch.cuda.is_available()
# Out:
# /opt/miniconda/envs/torch-nightly/lib/python3.11/site-packages/torch/_subclasses/functional_tensor.py:307: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# ('2.11.0.dev20260123+cpu', False)

# %%
import torch
torch.__version__, torch.cuda.is_available()
# Out:
# ('2.11.0.dev20260123+cpu', False)

# %%
from transformers import AutoTokenizer, AutoModel

print("Transformers imported successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from transformers import AutoTokenizer, AutoModel
#       3 print("Transformers imported successfully")
#
# ModuleNotFoundError: No module named 'transformers'

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="sshleifer/tiny-gpt2")
pipe("Hello Bugworld")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from transformers import pipeline
#       3 pipe = pipeline("text-generation", model="sshleifer/tiny-gpt2")
#       4 pipe("Hello Bugworld")
#
# ModuleNotFoundError: No module named 'transformers'

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="sshleifer/tiny-gpt2")
pipe("Hello Bugworld")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from transformers import pipeline
#       3 pipe = pipeline("text-generation", model="sshleifer/tiny-gpt2")
#       4 pipe("Hello Bugworld")
#
# ModuleNotFoundError: No module named 'transformers'

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="sshleifer/tiny-gpt2")
pipe("Hello Bugworld")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import pipeline
#       3 pipe = pipeline("text-generation", model="sshleifer/tiny-gpt2")
#       4 pipe("Hello Bugworld")
#
# ModuleNotFoundError: No module named 'transformers'

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="sshleifer/tiny-gpt2")
pipe("Hello Bugworld")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import pipeline
#       3 pipe = pipeline("text-generation", model="sshleifer/tiny-gpt2")
#       4 pipe("Hello Bugworld")
#
# ModuleNotFoundError: No module named 'transformers'

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="sshleifer/tiny-gpt2")
pipe("Hello Bugworld")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import pipeline
#       3 pipe = pipeline("text-generation", model="sshleifer/tiny-gpt2")
#       4 pipe("Hello Bugworld")
#
# ModuleNotFoundError: No module named 'transformers'
